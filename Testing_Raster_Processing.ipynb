# %% [markdown]
# Libraries used

# %%
import numpy as np
from osgeo import gdal
import matplotlib.pyplot as plt

# %% [markdown]
# Defining a function to import and view the raster bands

# %%
def import_and_plot(stack_filepath, band_index):
    
    """Imports the raster stack using gdal
       Then convert a selected band into a numpy array
       Then plots the 1-band image
       
       Requires:
           The file path for the raster stack
           The index value of the desired raster band
           
       Outputs:
           An image of the i-th band of the raster stack"""
    
    # Import
    raster_stack = gdal.Open(stack_filepath)
    # Convert
    raster_array = raster_stack.GetRasterBand(band_index).ReadAsArray()
    # Plot
    plt.imshow(raster_array);

# %% [markdown]
# # 10m Rasters

# %%
import_and_plot("Denver10.tif", 1)

# %%
import_and_plot("Denver10.tif", 2)

# %%
import_and_plot("Denver10.tif", 3)

# %%
import_and_plot("Denver10.tif", 4)

# %% [markdown]
# # 20m Rasters

# %%
import_and_plot("Denver20.tif", 1)

# %%
import_and_plot("Denver20.tif", 2)

# %%
import_and_plot("Denver20.tif", 3)

# %%
import_and_plot("Denver20.tif", 4)

# %%
import_and_plot("Denver20.tif", 5)

# %% [markdown]
# # 60m Rasters

# %%
import_and_plot("Denver60.tif", 1)

# %%
import_and_plot("Denver60.tif", 2)

# %%
import_and_plot("Denver60.tif", 3)
